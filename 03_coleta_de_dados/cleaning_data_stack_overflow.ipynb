# %%
import pandas as pd
import datetime as dt
import re, math
import numpy as np

# %%
df = pd.read_csv('Stack_Overflow_Jobs.csv')
df.head()
# Out:
#                            company  \
# 0                       Kindred AI
# 1                  Articulate Inc.
# 2                   Challengermode
# 3  Compliance Solutions Strategies
# 4                       Celonis SE
#
#                                             location         perks    posted  \
# 0  \r\r\n             - \r\r\nToronto, ON, Canada...           NaN  < 1h ago
# 1  \r\r\n             - \r\r\nNo office location ...        Remote  < 1h ago
# 2  \r\r\n             - \r\r\nStockholm, Sweden  ...  Visa sponsor  < 1h ago
# 3    \r\r\n             - \r\r\nNew York, NY                   NaN  < 1h ago
# 4  \r\r\n             - \r\r\nMünchen, Germany   ...           NaN  < 1h ago
#
#                  request_date  \
# 0  2018-11-15 13:42:44.056522
# 1  2018-11-15 13:42:44.058503
# 2  2018-11-15 13:42:44.059503
# 3  2018-11-15 13:42:44.061502
# 4  2018-11-15 13:42:44.063500
#
#                                               salary  \
# 0                                       C$90k - 110k
# 1                                                NaN
# 2  SEK 420k - 624k\r\r\n\r\r\n                   ...
# 3                                                NaN
# 4                                                NaN
#
#                                                 tags  \
# 0                                       scrum, agile
# 1  node.js, amazon-web-services, terraform, docke...
# 2           c#, asp.net, angularjs, javascript, .net
# 3                      c#, .net, javascript, node.js
# 4            java, spring, java-ee, rest, springboot
#
#                                              title
# 0                        Technical Program Manager
# 1                                Platform Engineer
# 2  Fullstack Web Developer at Esports Tech Startup
# 3                          Front to back Developer
# 4                            Senior Java Developer

# %%
df.shape
# Out:
# (1050, 8)

# %% [markdown]
# ### Processando a coluna Location

# %%
def clear_location(x):
    if 'No office location' in x:
        return None
    
    loc = x.split()
    if '-' in loc:
        loc.remove('-')
    return ' '.join(loc)

df['location'] = df['location'].apply(clear_location)
df.head()
# Out:
#                            company             location         perks  \
# 0                       Kindred AI  Toronto, ON, Canada           NaN
# 1                  Articulate Inc.                 None        Remote
# 2                   Challengermode    Stockholm, Sweden  Visa sponsor
# 3  Compliance Solutions Strategies         New York, NY           NaN
# 4                       Celonis SE     München, Germany           NaN
#
#      posted                request_date  \
# 0  < 1h ago  2018-11-15 13:42:44.056522
# 1  < 1h ago  2018-11-15 13:42:44.058503
# 2  < 1h ago  2018-11-15 13:42:44.059503
# 3  < 1h ago  2018-11-15 13:42:44.061502
# 4  < 1h ago  2018-11-15 13:42:44.063500
#
#                                               salary  \
# 0                                       C$90k - 110k
# 1                                                NaN
# 2  SEK 420k - 624k\r\r\n\r\r\n                   ...
# 3                                                NaN
# 4                                                NaN
#
#                                                 tags  \
# 0                                       scrum, agile
# 1  node.js, amazon-web-services, terraform, docke...
# 2           c#, asp.net, angularjs, javascript, .net
# 3                      c#, .net, javascript, node.js
# 4            java, spring, java-ee, rest, springboot
#
#                                              title
# 0                        Technical Program Manager
# 1                                Platform Engineer
# 2  Fullstack Web Developer at Esports Tech Startup
# 3                          Front to back Developer
# 4                            Senior Java Developer

# %% [markdown]
# ### Criando a coluna Country

# %%
def separate_country(row):
    if not row.location:
        row['location'], row['country'] = (None, None)
    else:
        row['location'], _, row['country'] = row.location.partition(', ')
        
    return row
    
df = df.apply(separate_country, axis=1)
df.head()
# Out:
#                            company   location         perks    posted  \
# 0                       Kindred AI    Toronto           NaN  < 1h ago
# 1                  Articulate Inc.       None        Remote  < 1h ago
# 2                   Challengermode  Stockholm  Visa sponsor  < 1h ago
# 3  Compliance Solutions Strategies   New York           NaN  < 1h ago
# 4                       Celonis SE    München           NaN  < 1h ago
#
#                  request_date  \
# 0  2018-11-15 13:42:44.056522
# 1  2018-11-15 13:42:44.058503
# 2  2018-11-15 13:42:44.059503
# 3  2018-11-15 13:42:44.061502
# 4  2018-11-15 13:42:44.063500
#
#                                               salary  \
# 0                                       C$90k - 110k
# 1                                                NaN
# 2  SEK 420k - 624k\r\r\n\r\r\n                   ...
# 3                                                NaN
# 4                                                NaN
#
#                                                 tags  \
# 0                                       scrum, agile
# 1  node.js, amazon-web-services, terraform, docke...
# 2           c#, asp.net, angularjs, javascript, .net
# 3                      c#, .net, javascript, node.js
# 4            java, spring, java-ee, rest, springboot
#
#                                              title     country
# 0                        Technical Program Manager  ON, Canada
# 1                                Platform Engineer        None
# 2  Fullstack Web Developer at Esports Tech Startup      Sweden
# 3                          Front to back Developer          NY
# 4                            Senior Java Developer     Germany

# %% [markdown]
# ### Processando a coluna Posted

# %%
df.posted.unique()
# Out:
# array(['< 1h ago', '1h ago', '2h ago', '3h ago', '5h ago', '4h ago',
#        '6h ago', '7h ago', '8h ago', '10h ago', '9h ago', '11h ago',
#        '12h ago', '13h ago', '14h ago', '15h ago', '16h ago', '18h ago',
#        '17h ago', '19h ago', '20h ago', '22h ago', '21h ago', '23h ago',
#        'yesterday', '2d ago', '3d ago'], dtype=object)

# %%
def replace_times_ago_to_date(row):
    times_ago, req_date = row['posted'], row['request_date']
    
    req_date = dt.datetime.strptime(req_date, "%Y-%m-%d %H:%M:%S.%f")
    numero = re.sub('[^\d]', '',times_ago)

    if 'h ago' in times_ago:
        return req_date - dt.timedelta(hours= int(numero))
    elif 'd ago' in times_ago:
        return req_date - dt.timedelta(days= int(numero))
    else:
        return req_date - dt.timedelta(days= 1)
                 
df['posted'] = df.apply(replace_times_ago_to_date, axis=1)
df.head()
# Out:
#                            company   location         perks  \
# 0                       Kindred AI    Toronto           NaN
# 1                  Articulate Inc.       None        Remote
# 2                   Challengermode  Stockholm  Visa sponsor
# 3  Compliance Solutions Strategies   New York           NaN
# 4                       Celonis SE    München           NaN
#
#                       posted                request_date  \
# 0 2018-11-15 12:42:44.056522  2018-11-15 13:42:44.056522
# 1 2018-11-15 12:42:44.058503  2018-11-15 13:42:44.058503
# 2 2018-11-15 12:42:44.059503  2018-11-15 13:42:44.059503
# 3 2018-11-15 12:42:44.061502  2018-11-15 13:42:44.061502
# 4 2018-11-15 12:42:44.063500  2018-11-15 13:42:44.063500
#
#                                               salary  \
# 0                                       C$90k - 110k
# 1                                                NaN
# 2  SEK 420k - 624k\r\r\n\r\r\n                   ...
# 3                                                NaN
# 4                                                NaN
#
#                                                 tags  \
# 0                                       scrum, agile
# 1  node.js, amazon-web-services, terraform, docke...
# 2           c#, asp.net, angularjs, javascript, .net
# 3                      c#, .net, javascript, node.js
# 4            java, spring, java-ee, rest, springboot
#
#                                              title     country
# 0                        Technical Program Manager  ON, Canada
# 1                                Platform Engineer        None
# 2  Fullstack Web Developer at Esports Tech Startup      Sweden
# 3                          Front to back Developer          NY
# 4                            Senior Java Developer     Germany

# %%
df = df.drop(['request_date'], axis=1)

# %% [markdown]
# ### Processando a coluna Salary

# %%
# Valor para conversão de uma moeda para Real
moedas = {
    'R$': 1, # Real
    'C$': 2.88, # Dolar Canadense
    '£': 4.91, # Libra esterlina, Reino Unido
    '€': 4.30, # Euro
    '₹': 0.052, # Rúpia indiana
    'A$': 2.75, # Dolar Australiano
    'zł': 1, # Zloti polonês
    'SEK': 0.42, # Coroa Sueca
    'CHF': 3.76, # Franco suíço
    'MXN': 0.19, # Peso mexicano
    'R': 0.26, # Rand Sul-Africano
    '$': 3.78, # Dolar Americano
}

# %%
def clear_salary(row):
    row['moeda_original'] = '-'
    
    if isinstance(row['salary'], float):
        return row
    
    for moeda in moedas.keys():
        if moeda in row['salary']:
            min_max_list = re.sub('[^\d-]','', row['salary']).split('-')

            if len(min_max_list) == 2:
                row['salary_min'], row['salary_max'] = tuple(min_max_list)
            else:
                row['salary_max'] = min_max_list[0]

            row['moeda_original'] = moeda
            break
    
    return row

df = df.apply(clear_salary, axis=1)
df.head()
# Out:
#                            company     country   location moeda_original  \
# 0                       Kindred AI  ON, Canada    Toronto             C$
# 1                  Articulate Inc.        None       None              -
# 2                   Challengermode      Sweden  Stockholm            SEK
# 3  Compliance Solutions Strategies          NY   New York              -
# 4                       Celonis SE     Germany    München              -
#
#           perks                     posted  \
# 0           NaN 2018-11-15 12:42:44.056522
# 1        Remote 2018-11-15 12:42:44.058503
# 2  Visa sponsor 2018-11-15 12:42:44.059503
# 3           NaN 2018-11-15 12:42:44.061502
# 4           NaN 2018-11-15 12:42:44.063500
#
#                                               salary salary_max salary_min  \
# 0                                       C$90k - 110k        110         90
# 1                                                NaN        NaN        NaN
# 2  SEK 420k - 624k\r\r\n\r\r\n                   ...        624        420
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#                                                 tags  \
# 0                                       scrum, agile
# 1  node.js, amazon-web-services, terraform, docke...
# 2           c#, asp.net, angularjs, javascript, .net
# 3                      c#, .net, javascript, node.js
# 4            java, spring, java-ee, rest, springboot
#
#                                              title
# 0                        Technical Program Manager
# 1                                Platform Engineer
# 2  Fullstack Web Developer at Esports Tech Startup
# 3                          Front to back Developer
# 4                            Senior Java Developer

# %% [markdown]
# ### Replace Countries

# %%
df['country'] = df['country'].replace({
    'Deutschland': 'Alemanha',
    'Germany': 'Alemanha',
    'UK': 'Reino Unido',
    'Netherlands': 'Holanda',
    'Sweden': 'Suécia',
    'France': 'França',
    'Schweiz': 'Suíça',
    'Norway': 'Noruega',
    'Switzerland': 'Suíça',
    'Poland': 'Polônia',
    'Romania': 'Romênia',
    'Belgium': 'Bélgica',
    'Österreich': 'Áustria'
})

# %% [markdown]
# ### Replace Contry EUA

# %%
df['country'] = df['country'].replace({
    'TX': 'Texas, EUA',
    'CA': 'Califórnia, EUA',
    'VA': 'Virgínia, EUA',
    'NY': 'Nova York, EUA',
    'CO': 'Colorado, EUA',
    'PA': 'Pensilvânia, EUA',
    'MA': 'Massachusetts, EUA',
    'IL': 'Illinois, EUA',
    'NJ': 'Nova Jersey, EUA',
    'UT': 'Utah, EUA',
    'OH': 'Ohio, EUA',
    'FL': 'Flórida, EUA',
    'WI': 'Wisconsin, EUA',
    'DC': 'Washington, EUA',
    'TN': 'Tennessee, EUA',
    'MI': 'Michigan, EUA',
    'WA': 'Washington, EUA',
    'MD': 'Maryland, EUA',
    'IN': 'Indiana, EUA',
    'AZ': 'Arizona, EUA',
    'DE': 'Delaware, EUA',
    'GA': 'Georgia, EUA',
    'MO': 'Missouri, EUA',
    'NC': 'Carolina do Norte, EUA'
})

# %% [markdown]
# ### Convertendo a moeda para Real
#    - Converte cada valor para a moeda Real de acordo com a cotação definida em _moedas_
#    - Coverte o salário anual para mensal
#    - Calcula a média entre o mínimo e máximo

# %%
df[['salary_min', 'salary_max', 'salary']] = df[['salary_min', 'salary_max', 'salary']].fillna(0)
df.head()
# Out:
#                            company         country   location moeda_original  \
# 0                       Kindred AI      ON, Canada    Toronto             C$
# 1                  Articulate Inc.            None       None              -
# 2                   Challengermode          Suécia  Stockholm            SEK
# 3  Compliance Solutions Strategies  Nova York, EUA   New York              -
# 4                       Celonis SE        Alemanha    München              -
#
#           perks                     posted  \
# 0           NaN 2018-11-15 12:42:44.056522
# 1        Remote 2018-11-15 12:42:44.058503
# 2  Visa sponsor 2018-11-15 12:42:44.059503
# 3           NaN 2018-11-15 12:42:44.061502
# 4           NaN 2018-11-15 12:42:44.063500
#
#                                               salary salary_max salary_min  \
# 0                                       C$90k - 110k        110         90
# 1                                                  0          0          0
# 2  SEK 420k - 624k\r\r\n\r\r\n                   ...        624        420
# 3                                                  0          0          0
# 4                                                  0          0          0
#
#                                                 tags  \
# 0                                       scrum, agile
# 1  node.js, amazon-web-services, terraform, docke...
# 2           c#, asp.net, angularjs, javascript, .net
# 3                      c#, .net, javascript, node.js
# 4            java, spring, java-ee, rest, springboot
#
#                                              title
# 0                        Technical Program Manager
# 1                                Platform Engineer
# 2  Fullstack Web Developer at Esports Tech Startup
# 3                          Front to back Developer
# 4                            Senior Java Developer

# %%
def converter_para_real(row):
    moeda = 0
    if row['moeda_original'] != '-':
        moeda = moedas[row['moeda_original']]
        
    row['salary_min'] = math.floor((moeda * int(row['salary_min'])) / 12)
    row['salary_max'] = math.ceil((moeda * int(row['salary_max'])) / 12)
    row['salary_mean'] = row[['salary_min','salary_max']].mean()
    return row

df = df.apply(converter_para_real, axis=1)
df = df.drop(['salary'], axis=1)
df.head()
# Out:
#                            company         country   location moeda_original  \
# 0                       Kindred AI      ON, Canada    Toronto             C$
# 1                  Articulate Inc.            None       None              -
# 2                   Challengermode          Suécia  Stockholm            SEK
# 3  Compliance Solutions Strategies  Nova York, EUA   New York              -
# 4                       Celonis SE        Alemanha    München              -
#
#           perks                     posted  salary_max  salary_min  \
# 0           NaN 2018-11-15 12:42:44.056522          27          21
# 1        Remote 2018-11-15 12:42:44.058503           0           0
# 2  Visa sponsor 2018-11-15 12:42:44.059503          22          14
# 3           NaN 2018-11-15 12:42:44.061502           0           0
# 4           NaN 2018-11-15 12:42:44.063500           0           0
#
#                                                 tags  \
# 0                                       scrum, agile
# 1  node.js, amazon-web-services, terraform, docke...
# 2           c#, asp.net, angularjs, javascript, .net
# 3                      c#, .net, javascript, node.js
# 4            java, spring, java-ee, rest, springboot
#
#                                              title  salary_mean
# 0                        Technical Program Manager         24.0
# 1                                Platform Engineer          0.0
# 2  Fullstack Web Developer at Esports Tech Startup         18.0
# 3                          Front to back Developer          0.0
# 4                            Senior Java Developer          0.0

# %%
df = df[['title','tags', 'perks', 'country','location', 'company', 'posted', 'moeda_original', 'salary_min', 'salary_max', 'salary_mean']]

# %%
df.to_csv('Stack_Overflow_Jobs2.csv', index=False)

# %% [markdown]
# ### Criando Data Frame para as Tags

# %%
job_tags = []

def separate_tags(row):
    tags_dic = {'id': row.name}

    if not isinstance(row['tags'], float):
        tags = row['tags']
        
        for tag in tags.split(', '):
            tags_dic[tag] = 1
    
    job_tags.append(tags_dic)
    return row
    
    
_ = df.apply(separate_tags, axis=1)

# %%
del job_tags[0]

# %%
df_tags = pd.DataFrame(job_tags)

# %%
df_tags.shape
# Out:
# (1050, 607)

# %%
df_tags.head()
# Out:
#    .net  .net-4.0  .net-core  3-tier  3d   4  ab-testing  abap  accessibility  \
# 0   NaN       NaN        NaN     NaN NaN NaN         NaN   NaN            NaN
# 1   NaN       NaN        NaN     NaN NaN NaN         NaN   NaN            NaN
# 2   1.0       NaN        NaN     NaN NaN NaN         NaN   NaN            NaN
# 3   1.0       NaN        NaN     NaN NaN NaN         NaN   NaN            NaN
# 4   NaN       NaN        NaN     NaN NaN NaN         NaN   NaN            NaN
#
#    acoustics       ...        workday  workfusion  wpf  wxwidgets  xamarin  \
# 0        NaN       ...            NaN         NaN  NaN        NaN      NaN
# 1        NaN       ...            NaN         NaN  NaN        NaN      NaN
# 2        NaN       ...            NaN         NaN  NaN        NaN      NaN
# 3        NaN       ...            NaN         NaN  NaN        NaN      NaN
# 4        NaN       ...            NaN         NaN  NaN        NaN      NaN
#
#    xcode  xml  yocto  yui  zend-framework
# 0    NaN  NaN    NaN  NaN             NaN
# 1    NaN  NaN    NaN  NaN             NaN
# 2    NaN  NaN    NaN  NaN             NaN
# 3    NaN  NaN    NaN  NaN             NaN
# 4    NaN  NaN    NaN  NaN             NaN
#
# [5 rows x 607 columns]

# %%
df_tags.to_csv('jobs_tags.csv', index=False)
