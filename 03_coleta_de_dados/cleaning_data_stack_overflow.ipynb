# %%
import pandas as pd
import datetime as dt
import re
import numpy as np

# %%
df = pd.read_csv('Stack_Overflow_Jobs.csv')
df.head()
# Out:
#                            company  \
# 0                        Corelight
# 1                        Lux Group
# 2                          TFG Co.
# 3                        Wallethub
# 4                        Wallethub
# 5                         Presence
# 6  ClearPoint Federal Bank & Trust
# 7          Manulife / John Hancock
# 8        S2P Project Professionals
# 9                        Corelight
#
#                                             location  \
# 0  \r\r\n             - \r\r\nSan Francisco, CA  ...
# 1  \r\r\n             - \r\r\nSydney, Australia  ...
# 2  \r\r\n             - \r\r\nState of São Paulo,...
# 3  \r\r\n             - \r\r\nNo office location ...
# 4  \r\r\n             - \r\r\nNo office location ...
# 5  \r\r\n             - \r\r\nSaint Petersburg, F...
# 6  \r\r\n             - \r\r\nBatesville, IN
# 7  \r\r\n             - \r\r\nKitchener, ON, Cana...
# 8  \r\r\n             - \r\r\nSydney, Australia  ...
# 9  \r\r\n             - \r\r\nSan Francisco, CA  ...
#
#                         perks    posted                request_date  \
# 0                Visa sponsor    5h ago  2018-11-13 02:38:16.258048
# 1                         NaN  < 1h ago  2018-11-13 02:38:16.258048
# 2                         NaN  < 1h ago  2018-11-13 02:38:16.258048
# 3                      Remote    2h ago  2018-11-13 02:38:16.258048
# 4                      Remote    2h ago  2018-11-13 02:38:16.258048
# 5             Paid relocation    3h ago  2018-11-13 02:38:16.258048
# 6                      Remote    3h ago  2018-11-13 02:38:16.273671
# 7  On-site and limited remote    3h ago  2018-11-13 02:38:16.273671
# 8                         NaN    4h ago  2018-11-13 02:38:16.273671
# 9                Visa sponsor    4h ago  2018-11-13 02:38:16.273671
#
#                                               salary  \
# 0  $120k - 170k\r\r\n\r\r\n                      ...
# 1                                      A$120k - 150k
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  $90k - 120k\r\r\n\r\r\n                       ...
# 6                                        $90k - 110k
# 7                                       C$85k - 115k
# 8                                      A$130k - 180k
# 9                                             Equity
#
#                                                 tags                title
# 0         user-interface, reactjs, go, node.js, rest       user-interface
# 1         web-services, javascript, reactjs, node.js         web-services
# 2             spark, presto, hive, kubernetes, kafka                spark
# 3                  spring, java, spring-mvc, java-ee               spring
# 4  selenium, java, automation, automated-tests, t...             selenium
# 5         angularjs, .net, c#, .net-core, javascript            angularjs
# 6            c#, ssms-2017, javascript, reactjs, git                   c#
# 7           java, javascript, c#, html5, react-relay                 java
# 8  amazon-web-services, java, automation, go, ans...  amazon-web-services
# 9  qa, python, testing, bash, continuous-integration                   qa

# %% [markdown]
# ### Processando a coluna Location

# %%
def clear_location(x):
    if 'No office location' in x:
        return None
    
    loc = x.split()
    if '-' in loc:
        loc.remove('-')
    return ' '.join(loc)

df['location'] = df['location'].apply(clear_location)
df.head()
# Out:
#      company                    location         perks    posted  \
# 0  Corelight           San Francisco, CA  Visa sponsor    5h ago
# 1  Lux Group           Sydney, Australia           NaN  < 1h ago
# 2    TFG Co.  State of São Paulo, Brazil           NaN  < 1h ago
# 3  Wallethub                        None        Remote    2h ago
# 4  Wallethub                        None        Remote    2h ago
#
#                  request_date  \
# 0  2018-11-13 02:38:16.258048
# 1  2018-11-13 02:38:16.258048
# 2  2018-11-13 02:38:16.258048
# 3  2018-11-13 02:38:16.258048
# 4  2018-11-13 02:38:16.258048
#
#                                               salary  \
# 0  $120k - 170k\r\r\n\r\r\n                      ...
# 1                                      A$120k - 150k
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 tags           title
# 0         user-interface, reactjs, go, node.js, rest  user-interface
# 1         web-services, javascript, reactjs, node.js    web-services
# 2             spark, presto, hive, kubernetes, kafka           spark
# 3                  spring, java, spring-mvc, java-ee          spring
# 4  selenium, java, automation, automated-tests, t...        selenium

# %% [markdown]
# ### Criando a coluna Country

# %%
def separate_country(row):
    if not row.location:
        row['location'], row['country'] = (None, None)
    else:
        row['location'], _, row['country'] = row.location.partition(', ')
        
    return row
    
df = df.apply(separate_country, axis=1)
df.head()
# Out:
#      company            location         perks    posted  \
# 0  Corelight       San Francisco  Visa sponsor    5h ago
# 1  Lux Group              Sydney           NaN  < 1h ago
# 2    TFG Co.  State of São Paulo           NaN  < 1h ago
# 3  Wallethub                None        Remote    2h ago
# 4  Wallethub                None        Remote    2h ago
#
#                  request_date  \
# 0  2018-11-13 02:38:16.258048
# 1  2018-11-13 02:38:16.258048
# 2  2018-11-13 02:38:16.258048
# 3  2018-11-13 02:38:16.258048
# 4  2018-11-13 02:38:16.258048
#
#                                               salary  \
# 0  $120k - 170k\r\r\n\r\r\n                      ...
# 1                                      A$120k - 150k
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 tags           title  \
# 0         user-interface, reactjs, go, node.js, rest  user-interface
# 1         web-services, javascript, reactjs, node.js    web-services
# 2             spark, presto, hive, kubernetes, kafka           spark
# 3                  spring, java, spring-mvc, java-ee          spring
# 4  selenium, java, automation, automated-tests, t...        selenium
#
#      country
# 0         CA
# 1  Australia
# 2     Brazil
# 3       None
# 4       None

# %% [markdown]
# ### Processando a coluna Posted

# %%
df.posted.unique()
# Out:
# array(['5h ago', '< 1h ago', '2h ago', '3h ago', '4h ago', '6h ago',
#        '7h ago', '8h ago', '9h ago', '10h ago', '11h ago', '13h ago',
#        '12h ago', '14h ago', '15h ago', '16h ago', '17h ago', '18h ago',
#        '19h ago', '20h ago', '21h ago', 'yesterday', '22h ago', '23h ago',
#        '2d ago', '3d ago', '4d ago'], dtype=object)

# %%
def replace_times_ago_to_date(row):
    times_ago, req_date = row['posted'], row['request_date']
    
    req_date = dt.datetime.strptime(req_date, "%Y-%m-%d %H:%M:%S.%f")
    numero = re.sub('[^\d]', '',times_ago)

    if 'h ago' in times_ago:
        return req_date - dt.timedelta(hours= int(numero))
    elif 'd ago' in times_ago:
        return req_date - dt.timedelta(days= int(numero))
    else:
        return req_date - dt.timedelta(days= 1)
                 
df['posted'] = df.apply(replace_times_ago_to_date, axis=1)
df.head()
# Out:
#      company            location         perks                     posted  \
# 0  Corelight       San Francisco  Visa sponsor 2018-11-12 21:38:16.258048
# 1  Lux Group              Sydney           NaN 2018-11-13 01:38:16.258048
# 2    TFG Co.  State of São Paulo           NaN 2018-11-13 01:38:16.258048
# 3  Wallethub                None        Remote 2018-11-13 00:38:16.258048
# 4  Wallethub                None        Remote 2018-11-13 00:38:16.258048
#
#                  request_date  \
# 0  2018-11-13 02:38:16.258048
# 1  2018-11-13 02:38:16.258048
# 2  2018-11-13 02:38:16.258048
# 3  2018-11-13 02:38:16.258048
# 4  2018-11-13 02:38:16.258048
#
#                                               salary  \
# 0  $120k - 170k\r\r\n\r\r\n                      ...
# 1                                      A$120k - 150k
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 tags           title  \
# 0         user-interface, reactjs, go, node.js, rest  user-interface
# 1         web-services, javascript, reactjs, node.js    web-services
# 2             spark, presto, hive, kubernetes, kafka           spark
# 3                  spring, java, spring-mvc, java-ee          spring
# 4  selenium, java, automation, automated-tests, t...        selenium
#
#      country
# 0         CA
# 1  Australia
# 2     Brazil
# 3       None
# 4       None

# %%
df = df.drop(['request_date'], axis=1)

# %% [markdown]
# ### Processando a coluna Salary

# %%
def clear_salary(x):
    if not isinstance(x, float):
        salary = x.split()
        print(salary)

df['salary'].apply(clear_salary)
# Out:
# ['$120k', '-', '170k', '|', 'Equity']
# ['A$120k', '-', '150k']
# ['$90k', '-', '120k', '|', 'Equity']
# ['$90k', '-', '110k']
# ['C$85k', '-', '115k']
# ['A$130k', '-', '180k']
# ['Equity']
# ['$130k', '-', '175k']
# ['A$90k', '-', '175k', '|', 'Equity']
# ['$70k', '-', '75k']
# ['$180k', '-', '220k']
# ['$100k', '-', '150k']
# ['MXN', '710k', '-', '1018k']
# ['$75k', '-', '100k']
# ['$145k', '-', '175k', '|', 'Equity']
# ['$80k', '-', '140k', '|', 'Equity']
# ['$70k', '-', '80k']
# ['Equity']
# ['$80k', '-', '150k']
# ['£50k', '-', '125k']
# ['R$8k', '-', '8k']
# ['$20k', '-', '120k']
# ['$100k', '-', '120k']
# ['$75k', '-', '100k']
# ['£60k', '-', '85k']
# ['Equity']
# ['€55k', '-', '70k']
# ['£30k', '-', '47k']
# ['£30k', '-', '55k']
# ['$60k', '-', '70k']
# ['Equity']
# ['$170k', '-', '200k', '|', 'Equity']
# ['£25k', '-', '35k']
# ['$24k', '-', '48k']
# ['€35k', '-', '55k']
# ['$50k', '-', '65k']
# ['Equity']
# ['£65k', '-', '85k']
# ['$85k', '-', '120k']
# ['£45k', '-', '60k']
# ['R$144k', '-', '168k']
# ['€38k', '-', '43k']
# ['$80k', '-', '140k']
# ['C$60k', '-', '90k']
# ['SEK', '402k', '-', '480k']
# ['£50k', '-', '80k']
# ['Equity']
# ['Equity']
# ['C$75k', '-', '120k', '|', 'Equity']
# ['€50k', '-', '75k']
# ['£35k', '-', '50k']
# ['Equity']
# ['£70k', '-', '90k']
# ['€30k', '-', '40k']
# ['£50k', '-', '90k']
# ['€40k', '-', '70k']
# ['Equity']
# ['€40k', '-', '50k']
# ['€62k', '-', '78k']
# ['£45k', '-', '60k']
# ['£50k', '-', '60k']
# ['€35k', '-', '57k']
# ['£70k', '-', '90k']
# ['€40k', '-', '60k']
# ['€60k', '-', '80k']
# ['€11k', '-', '14k']
# ['€60k', '-', '80k']
# ['£60k', '-', '90k']
# ['€60k', '-', '80k']
# ['€45k', '-', '80k']
# ['€40k', '-', '70k']
# ['£45k', '-', '80k', '|', 'Equity']
# ['€60k', '-', '80k']
# ['€60k', '-', '80k']
# ['€50k', '-', '75k']
# ['£35k', '-', '50k']
# ['£38k', '-', '58k']
# ['€60k', '-', '100k', '|', 'Equity']
# ['€65k', '-', '85k']
# ['£44k', '-', '55k']
# ['₹600k', '-', '15000k']
# ['Equity']
# ['$80k', '-', '120k', '|', 'Equity']
# ['C$60k', '-', '100k']
# ['$50k', '-', '75k']
# ['$90k', '-', '130k', '|', 'Equity']
# ['$70k', '-', '125k', '|', 'Equity']
# ['Equity']
# ['Equity']
# ['Equity']
# ['Equity']
# ['Equity']
# ['A$75k', '-', '110k']
# ['$45k', '-', '65k']
# ['Equity']
# ['Equity']
# ['Equity']
# ['€45k', '-', '100k']
# ['Equity']
# ['$120k', '-', '155k', '|', 'Equity']
# ['Equity']
# ['$100k', '-', '135k', '|', 'Equity']
# ['$120k', '-', '140k', '|', 'Equity']
# ['$100k', '-', '130k']
# ['$99k', '-', '124k']
# ['$99k', '-', '124k']
# ['$0', '-', '1']
# ['$100k', '-', '150k', '|', 'Equity']
# ['C$80k', '-', '120k']
# ['£50k', '-', '65k']
# ['$120k', '-', '140k', '|', 'Equity']
# ['$60k', '-', '80k']
# ['$100k', '-', '160k', '|', 'Equity']
# ['C$50k', '-', '70k']
# ['Equity']
# ['$70k', '-', '95k']
# ['C$65k', '-', '70k']
# ['€18k', '-', '36k']
# ['€50k', '-', '70k']
# ['$100k', '-', '150k', '|', 'Equity']
# ['£26k', '-', '38k']
# ['R720k', '-', '1080k']
# ['€40k', '-', '65k']
# ['£34k', '-', '40k']
# ['$60k', '-', '90k', '|', 'Equity']
# ['$65k', '-', '95k']
# ['€40k', '-', '49k']
# ['Equity']
# ['€58k', '-', '70k']
# ['€55k', '-', '72k']
# ['€50k', '-', '60k']
# ['€24k', '-', '27k']
# ['€45k', '-', '65k']
# ['€60k', '-', '80k']
# ['€50k', '-', '80k']
# ['€40k', '-', '70k']
# ['€35k', '-', '55k']
# ['€45k', '-', '60k']
# ['€45k', '-', '60k']
# ['€45k', '-', '60k']
# ['€65k', '-', '75k']
# ['€45k', '-', '60k']
# ['€34k', '-', '46k']
# ['£40k', '-', '45k']
# ['£45k', '-', '55k']
# ['€42', '-', '62']
# ['€60k', '-', '80k']
# ['€60k', '-', '68k']
# ['€60k', '-', '80k']
# ['SEK', '396k', '-', '480k']
# ['SEK', '360k', '-', '720k']
# ['£24k', '-', '37k']
# ['CHF', '100k', '-', '150k', '|', 'Equity']
# ['$40k', '-', '60k', '|', 'Equity']
# ['Equity']
# ['€24k', '-', '42k', '|', 'Equity']
# ['$75k', '-', '120k', '|', 'Equity']
# ['$0', '-', '1']
# ['$0', '-', '1']
# ['$90k', '-', '125k']
# ['£45k', '-', '80k', '|', 'Equity']
# ['£45k', '-', '80k', '|', 'Equity']
# ['A$100k', '-', '115k']
# ['Equity']
# ['A$120k', '-', '160k']
# ['€50k', '-', '75k', '|', 'Equity']
# ['$80k', '-', '125k', '|', 'Equity']
# ['€50k', '-', '85k', '|', 'Equity']
# ['$140k', '-', '185k', '|', 'Equity']
# ['Equity']
# ['€40k', '-', '60k', '|', 'Equity']
# ['C$48k', '-', '69k', '|', 'Equity']
# ['C$52k', '-', '75k', '|', 'Equity']
# ['$130k', '-', '160k', '|', 'Equity']
# ['$65k', '-', '95k']
# ['Equity']
# ['€50k', '-', '90k']
# ['$24k', '-', '48k', '|', 'Equity']
# ['Equity']
# ['$70k', '-', '100k']
# ['Equity']
# ['$130k', '-', '150k', '|', 'Equity']
# ['$150k', '-', '200k']
# ['Equity']
# ['€50k', '-', '80k']
# ['€40k', '-', '80k']
# ['£70k', '-', '80k']
# ['£70k', '-', '75k']
# ['€55', '-', '60']
# ['£50k', '-', '75k', '|', 'Equity']
# ['£30k', '-', '42k']
# ['€25k', '-', '50k']
# ['€35k', '-', '60k']
# ['$90k', '-', '125k']
# ['£60k', '-', '75k']
# ['$75k', '-', '100k']
# ['€45k', '-', '70k']
# ['£35k', '-', '60k']
# ['€40k', '-', '65k']
# ['$70k', '-', '125k']
# ['$46k', '-', '78k']
# ['$60k', '-', '135k', '|', 'Equity']
# ['£40k', '-', '90k']
# ['Equity']
# ['€36k', '-', '50k']
# ['£45k', '-', '90k']
# ['£40k', '-', '80k']
# ['£40k', '-', '70k']
# ['£60k', '-', '95k']
# ['€50k', '-', '75k']
# ['€38k', '-', '50k']
# ['€50k', '-', '75k']
# ['£65k', '-', '90k']
# ['€42k', '-', '65k']
# ['€44k', '-', '60k']
# ['€55k', '-', '70k']
# ['Equity']
# ['€45k', '-', '55k', '|', 'Equity']
# ['zł120k', '-', '180k']
# ['$130k', '-', '170k', '|', 'Equity']
# ['£50k', '-', '90k', '|', 'Equity']
# ['€50k', '-', '75k']
# ['£53k', '-', '72k']
# ['€45k', '-', '55k']
# ['£35k', '-', '65k']
# ['£45k', '-', '65k']
# ['€50k', '-', '80k']
# ['€40k', '-', '60k']
# ['€60k', '-', '65k']
# ['Equity']
# ['€60k', '-', '80k']
# ['$35', '-', '48']
# ['$50k', '-', '80k']
# ['$60k', '-', '100k']
# ['A$120k', '-', '160k']
# ['A$75k', '-', '110k']
# ['$75k', '-', '90k']
# ['A$80k', '-', '95k']
# ['$80k', '-', '150k']
# ['C$80k', '-', '120k']
# ['C$80k', '-', '120k', '|', 'Equity']
# ['$100k', '-', '200k', '|', 'Equity']
# ['$16k', '-', '18k']
# ['$60k', '-', '75k']
# ['€40k', '-', '52k']
# ['$175k', '-', '210k', '|', 'Equity']
# ['$105k', '-', '140k', '|', 'Equity']
# ['$60k', '-', '100k']
# ['$90k', '-', '130k', '|', 'Equity']
# ['$90k', '-', '150k']
# ['$100k', '-', '180k', '|', 'Equity']
# ['$90k', '-', '120k']
# ['C$79k', '-', '96k']
# ['C$69k', '-', '84k']
# ['C$61k', '-', '84k']
# ['C$89k', '-', '109k']
# ['C$79k', '-', '96k']
# ['Equity']
# ['C$80k', '-', '95k']
# ['Equity']
# ['€50k', '-', '70k']
# ['£30k', '-', '40k']
# ['€50k', '-', '70k']
# ['$54k', '-', '72k']
# ['€40k', '-', '50k']
# ['€50k', '-', '70k']
# ['Equity']
# ['€50k', '-', '60k', '|', 'Equity']
# ['$150k', '-', '180k']
# ['€50k', '-', '120k']
# ['$70k', '-', '100k']
# ['Equity']
# ['€30', '-', '45']
# ['$24k', '-', '30k']
# ['£50k', '-', '80k']
# ['£45k', '-', '70k']
# ['£30k', '-', '45k']
# ['£24k', '-', '36k']
# ['$60k', '-', '85k']
# ['$130k', '-', '160k', '|', 'Equity']
# ['$90k', '-', '120k']
# ['£50k', '-', '70k']
# ['£60k', '-', '65k']
# ['Equity']
# ['€30k', '-', '51k']
# ['€30k', '-', '50k']
# ['€60k', '-', '90k']
# ['£80k', '-', '100k']
# ['£80k', '-', '120k']
# ['$130k', '-', '150k']
# ['€50k', '-', '75k']
# ['£50k', '-', '70k']
# ['€50k', '-', '75k']
# ['€22k', '-', '48k']
# ['€38k', '-', '58k']
# ['€42k', '-', '54k']
# ['£18k', '-', '37k']
# ['£55k', '-', '70k']
# ['€41k', '-', '70k']
# ['€65k', '-', '85k']
# ['$50k', '-', '80k']
# ['€35k', '-', '35k']
# ['€50k', '-', '65k']
# ['€45k', '-', '65k']
# ['£84k', '-', '96k']
# ['£55k', '-', '90k']
# ['CHF', '60k', '-', '70k']
# ['£65k', '-', '80k', '|', 'Equity']
# ['Equity']
# ['Equity']
# ['€55k', '-', '65k']
# ['€50k', '-', '65k']
# ['€50k', '-', '65k']
# ['£35k', '-', '65k']
# ['$36k', '-', '72k']
# ['$100k', '-', '170k', '|', 'Equity']
# ['Equity']
# ['Equity']
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 1020    None
# 1021    None
# 1022    None
# 1023    None
# 1024    None
# 1025    None
# 1026    None
# 1027    None
# 1028    None
# 1029    None
# 1030    None
# 1031    None
# 1032    None
# 1033    None
# 1034    None
# 1035    None
# 1036    None
# 1037    None
# 1038    None
# 1039    None
# 1040    None
# 1041    None
# 1042    None
# 1043    None
# 1044    None
# 1045    None
# 1046    None
# 1047    None
# 1048    None
# 1049    None
# Name: salary, Length: 1050, dtype: object

# %%
df[]

# %%
# Valor para conversão de uma moeda para Real
moedas = {
    'R$': 1, # Real
    '$': , # Dolar Americano
    'C$': 2.88, # Dolar Canadense
    '£': 2.88, # Dolar Canadense
    '€': 2.88, # Dolar Canadense
    '₹': 2.88, # Dolar Canadense
    'A$': 2.88, # Dolar Canadense
    'zł': 2.88, # Dolar Canadense
    'R': 2.88, # Dolar Canadense
    'SEK': 2.88, # Dolar Canadense
    'CHF': 2.88, # Dolar Canadense
    'MXN' 2.88, # Dolar Canadense
}
