# %% [markdown]
# ## Instituto Federal do Sudeste de Minas Gerais, Campus Barbacena
# ### Projeto Laboratório de Redes de Conhecimento

# %% [markdown]
# ## Curso de Mineração de Dados Aplicada
#
# Prof. Rafael José de Alencar Almeida
# <rafael.alencar@ifsudestemg.edu.br>
#
# <br>
#
# ## Aula 5:  Transformação de dados
#
# - É comum as features (colunas) possuírem faixas de valor muito diferentes (ex.: altura e idade)
# - Nem sempre a distruição dos dados é uma distribuição normal (gaussiana)
# - A maioria dos modelos de mineração de dados beneficia-se de dados de entrada que estejam bem escalados e distribuídos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from unicodedata import normalize
from string import punctuation
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import  cosine_similarity
# %matplotlib inline

from sklearn.preprocessing import *

# %% [markdown]
# ### Dataset para testes
#
# Red Wine Dataset

# %%
df_wine = pd.read_csv('https://raw.githubusercontent.com/rafjaa/machine_learning_fecib/master/src/wine-quality-classifier/dados/winequality-red.csv', sep=';')
df_wine.head()
# Out:
#    Acidez fixa  Acidez volátil  Ácido cítrico  Açúcar residual  Cloretos  \
# 0          7.4            0.70           0.00              1.9     0.076
# 1          7.8            0.88           0.00              2.6     0.098
# 2          7.8            0.76           0.04              2.3     0.092
# 3         11.2            0.28           0.56              1.9     0.075
# 4          7.4            0.70           0.00              1.9     0.076
#
#    Dióxido de enxofre livre  Dióxido de enxofre total  Densidade    pH  \
# 0                      11.0                      34.0     0.9978  3.51
# 1                      25.0                      67.0     0.9968  3.20
# 2                      15.0                      54.0     0.9970  3.26
# 3                      17.0                      60.0     0.9980  3.16
# 4                      11.0                      34.0     0.9978  3.51
#
#    Sulfatos  Álcool  Qualidade
# 0      0.56     9.4          5
# 1      0.68     9.8          5
# 2      0.65     9.8          5
# 3      0.58     9.8          6
# 4      0.56     9.4          5

# %%
# Distribuição das features
df_wine.describe()
# Out:
#        Acidez fixa  Acidez volátil  Ácido cítrico  Açúcar residual  \
# count  1599.000000     1599.000000    1599.000000      1599.000000
# mean      8.319637        0.527821       0.270976         2.538806
# std       1.741096        0.179060       0.194801         1.409928
# min       4.600000        0.120000       0.000000         0.900000
# 25%       7.100000        0.390000       0.090000         1.900000
# 50%       7.900000        0.520000       0.260000         2.200000
# 75%       9.200000        0.640000       0.420000         2.600000
# max      15.900000        1.580000       1.000000        15.500000
#
#           Cloretos  Dióxido de enxofre livre  Dióxido de enxofre total  \
# count  1599.000000               1599.000000               1599.000000
# mean      0.087467                 15.874922                 46.467792
# std       0.047065                 10.460157                 32.895324
# min       0.012000                  1.000000                  6.000000
# 25%       0.070000                  7.000000                 22.000000
# 50%       0.079000                 14.000000                 38.000000
# 75%       0.090000                 21.000000                 62.000000
# max       0.611000                 72.000000                289.000000
#
#          Densidade           pH     Sulfatos       Álcool    Qualidade
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean      0.996747     3.311113     0.658149    10.422983     5.636023
# std       0.001887     0.154386     0.169507     1.065668     0.807569
# min       0.990070     2.740000     0.330000     8.400000     3.000000
# 25%       0.995600     3.210000     0.550000     9.500000     5.000000
# 50%       0.996750     3.310000     0.620000    10.200000     6.000000
# 75%       0.997835     3.400000     0.730000    11.100000     6.000000
# max       1.003690     4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# ### Normalizer
# Normaliza os valores de cada linha

# %%
nm = Normalizer()
pd.DataFrame(
    nm.fit_transform(df_wine),
    columns=df_wine.columns
).head()
# Out:
#    Acidez fixa  Acidez volátil  Ácido cítrico  Açúcar residual  Cloretos  \
# 0     0.193478        0.018302       0.000000         0.049677  0.001987
# 1     0.106989        0.012071       0.000000         0.035663  0.001344
# 2     0.134949        0.013149       0.000692         0.039793  0.001592
# 3     0.173611        0.004340       0.008681         0.029452  0.001163
# 4     0.193478        0.018302       0.000000         0.049677  0.001987
#
#    Dióxido de enxofre livre  Dióxido de enxofre total  Densidade        pH  \
# 0                  0.287602                  0.888952   0.026088  0.091771
# 1                  0.342913                  0.919006   0.013673  0.043893
# 2                  0.259517                  0.934261   0.017249  0.056402
# 3                  0.263517                  0.930059   0.015470  0.048983
# 4                  0.287602                  0.888952   0.026088  0.091771
#
#    Sulfatos    Álcool  Qualidade
# 0  0.014642  0.245769   0.130728
# 1  0.009327  0.134422   0.068583
# 2  0.011246  0.169551   0.086506
# 3  0.008991  0.151910   0.093006
# 4  0.014642  0.245769   0.130728

# %% [markdown]
# ### StandardScaler
#
# - Normaliza os valores das colunas para uma distribuição mais próxima da normal.
#
# - É a transformação mais utilizada antes de enviar os dados para um modelo.
#
# <img src="./img/standardscaler.png">
#
# <strong>Fonte:</strong> http://benalexkeen.com/feature-scaling-with-scikit-learn/

# %%
std = StandardScaler()
pd.DataFrame(
    std.fit_transform(df_wine),
    columns=df_wine.columns
).head()
# Out:
# /home/aluno/miniconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/aluno/miniconda3/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#    Acidez fixa  Acidez volátil  Ácido cítrico  Açúcar residual  Cloretos  \
# 0    -0.528360        0.961877      -1.391472        -0.453218 -0.243707
# 1    -0.298547        1.967442      -1.391472         0.043416  0.223875
# 2    -0.298547        1.297065      -1.186070        -0.169427  0.096353
# 3     1.654856       -1.384443       1.484154        -0.453218 -0.264960
# 4    -0.528360        0.961877      -1.391472        -0.453218 -0.243707
#
#    Dióxido de enxofre livre  Dióxido de enxofre total  Densidade        pH  \
# 0                 -0.466193                 -0.379133   0.558274  1.288643
# 1                  0.872638                  0.624363   0.028261 -0.719933
# 2                 -0.083669                  0.229047   0.134264 -0.331177
# 3                  0.107592                  0.411500   0.664277 -0.979104
# 4                 -0.466193                 -0.379133   0.558274  1.288643
#
#    Sulfatos    Álcool  Qualidade
# 0 -0.579207 -0.960246  -0.787823
# 1  0.128950 -0.584777  -0.787823
# 2 -0.048089 -0.584777  -0.787823
# 3 -0.461180 -0.584777   0.450848
# 4 -0.579207 -0.960246  -0.787823

# %% [markdown]
# ### MinMaxScaler
#
# Normaliza todos valores em uma faixa de valores definida por <code>feature_range</code>.

# %%
mm = MinMaxScaler(feature_range=(0, 100))
pd.DataFrame(
    mm.fit_transform(df_wine),
    columns=df_wine.columns
).head()
# Out:
# /home/aluno/miniconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#    Acidez fixa  Acidez volátil  Ácido cítrico  Açúcar residual   Cloretos  \
# 0    24.778761       39.726027            0.0         6.849315  10.684474
# 1    28.318584       52.054795            0.0        11.643836  14.357262
# 2    28.318584       43.835616            4.0         9.589041  13.355593
# 3    58.407080       10.958904           56.0         6.849315  10.517529
# 4    24.778761       39.726027            0.0         6.849315  10.684474
#
#    Dióxido de enxofre livre  Dióxido de enxofre total  Densidade         pH  \
# 0                 14.084507                  9.893993  56.754772  60.629921
# 1                 33.802817                 21.554770  49.412628  36.220472
# 2                 19.718310                 16.961131  50.881057  40.944882
# 3                 22.535211                 19.081272  58.223201  33.070866
# 4                 14.084507                  9.893993  56.754772  60.629921
#
#     Sulfatos     Álcool  Qualidade
# 0  13.772455  15.384615       40.0
# 1  20.958084  21.538462       40.0
# 2  19.161677  21.538462       40.0
# 3  14.970060  21.538462       60.0
# 4  13.772455  15.384615       40.0

# %% [markdown]
# ## Redução de dimensionalidade
#
# - Consiste em se reduzir o número de colunas matriz de dados, preservando o máximo de informação.
# - Útil para quando o dataset é muito grande, possui muito ruído e quando se quer visualizar mais de 3 dimensões.
# - Diversas técnicas: PCA, NMF, SVD, ICA, etc.

# %% [markdown]
# ### PCA (Principal Component Analysis)
#
# - PCA é uma das mais comuns, e tem como vantagem ser determinística.
#
# <img src="http://www.sthda.com/sthda/RDoc/figure/factor-analysis/principal-component-analysis-basics-scatter-plot-data-mining-1.png">

# %%
# Classifica as notas(3 a 5 = 0; 6 a 8 = 1)
df_wine['Qualidade'] = df_wine['Qualidade'].apply(lambda x: 0 if x < 6 else 1)

# Exibe gráfico
df_wine.groupby('Qualidade').count()['Álcool'].plot(kind='bar', title='Vinhos bons(1) e ruins(0)')

# %%
# Normaliza os dados
df_std = pd.DataFrame(
    StandardScaler().fit_transform(df_wine.drop(['Qualidade'], axis=1)),
    columns=df_wine.columns.drop(['Qualidade'])
)

df_std['Qualidade'] = df_wine['Qualidade']

df_std.head()
# Out:
#    Acidez fixa  Acidez volátil  Ácido cítrico  Açúcar residual  Cloretos  \
# 0    -0.528360        0.961877      -1.391472        -0.453218 -0.243707
# 1    -0.298547        1.967442      -1.391472         0.043416  0.223875
# 2    -0.298547        1.297065      -1.186070        -0.169427  0.096353
# 3     1.654856       -1.384443       1.484154        -0.453218 -0.264960
# 4    -0.528360        0.961877      -1.391472        -0.453218 -0.243707
#
#    Dióxido de enxofre livre  Dióxido de enxofre total  Densidade        pH  \
# 0                 -0.466193                 -0.379133   0.558274  1.288643
# 1                  0.872638                  0.624363   0.028261 -0.719933
# 2                 -0.083669                  0.229047   0.134264 -0.331177
# 3                  0.107592                  0.411500   0.664277 -0.979104
# 4                 -0.466193                 -0.379133   0.558274  1.288643
#
#    Sulfatos    Álcool  Qualidade
# 0 -0.579207 -0.960246          0
# 1  0.128950 -0.584777          0
# 2 -0.048089 -0.584777          0
# 3 -0.461180 -0.584777          1
# 4 -0.579207 -0.960246          0

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6)

pca.fit_transform(
    df_std.drop(['Qualidade'], axis=1)
)
# Out:
# array([[-1.61952988,  0.45095009, -1.77445415,  0.04374031,  0.06701448,
#         -0.91392069],
#        [-0.79916993,  1.85655306, -0.91169017,  0.54806597, -0.01839156,
#          0.92971392],
#        [-0.74847909,  0.88203886, -1.17139423,  0.41102067, -0.04353101,
#          0.40147313],
#        ...,
#        [-1.45612897,  0.31174559,  1.12423941,  0.49187676,  0.19371564,
#         -0.50640956],
#        [-2.27051793,  0.97979111,  0.62796456,  0.63977007,  0.06773549,
#         -0.86040762],
#        [-0.42697475, -0.53669021,  1.6289552 , -0.39171595,  0.45048209,
#         -0.49615364]])

# %%
# Variação explicada dos dados
print(pca.explained_variance_ratio_)

print('O PCA conseguir explicar {0}% da variação dos dados'.format(
        pca.explained_variance_ratio_.sum() * 100
    ))
# Out:
# [0.28173931 0.1750827  0.1409585  0.11029387 0.08720837 0.05996439]
# O PCA conseguir explicar 85.52471350764364% da variação dos dados

# %%
# Visualizando a distribuição dos vinhos por qualidade

pca = PCA(n_components=3)

df_pca = pca.fit_transform(
    df_std.drop(['Qualidade'], axis=1)
)
df_pca = pd.DataFrame(df_pca)

df_pca['Qualidade'] = df_wine['Qualidade']
df_pca.head()
# Out:
#           0         1         2  Qualidade
# 0 -1.619530  0.450950 -1.774454          0
# 1 -0.799170  1.856553 -0.911690          0
# 2 -0.748479  0.882039 -1.171394          0
# 3  2.357673 -0.269976  0.243489          1
# 4 -1.619530  0.450950 -1.774454          0

# %%
groups = df_pca.groupby('Qualidade')

figure, axes = plt.subplots()
axes.margins(0.05)

for name, group in groups:
    axes.plot(group[0], group[1], marker='o', linestyle='', ms=6, label=name)

axes.legend()
plt.xlabel('Componente principal 1')
plt.ylabel('Componente principal 2')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

Axes3D.scatter(xs=df_pca[0],ys=df_pca[1], zs=df_pca[2], c='skyblue', s=60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-321311d12897> in <module>
#       2 ax = fig.add_subplot(111, projection='3d')
#       3
# ----> 4 Axes3D.scatter(xs=df_pca[0],ys=df_pca[1], zs=df_pca[2], c='skyblue', s=60)
#
# TypeError: scatter() missing 1 required positional argument: 'self'

# %% [markdown]
# ### Exercício
#
# Gere uma visualização 3D do dataset de vinhos.

# %% [markdown]
# ## Modelagem de tópicos (topic modeling)
#
# - Consiste em se reduzir a dimensionalidade de uma representação vetorial de textos para obter os assuntos semânticos (tópicos) mais relevantes.
# - Diversas técnicas (NMF, LDA, etc.)

# %% [markdown]
# ### NMF (Non-Negative Matrix Factorization)
#
# Fatora uma matriz M em duas sub-matrizes não negativas W e H, onde X =~ W * H
#
# <img src="./img/nmf.png">

# %%
from sklearn.decomposition import NMF

df = pd.read_csv('https://raw.githubusercontent.com/rafjaa/curso-mineracao-de-dados-aplicada/master/data/df_noticias_if.csv')
df.head()
# Out:
#          data                                             titulo  \
# 0  14/09/2017  Campus Barbacena divulga Resultado Provisório ...
# 1  14/09/2017  Divulgado o Edital de convocação de assembleia...
# 2  14/09/2017  Pesquisador da Bélgica realiza palestra no Cam...
# 3  14/09/2017  Divulgada a homologação das inscrições à candi...
# 4  14/09/2017  Aprovado Regulamento de Eventos, Cerimonial e ...
#
#                                             conteudo
# 0  \n\n\tO Campus Barbacena divulgou o Resultado ...
# 1  \n\n\tDivulgado o Edital de convocação de asse...
# 2  \n\n\tO pesquisador da Bélgica, Luc Vankrunkel...
# 3  \n\n\tDivulgada a homologação das inscrições à...
# 4  \n\n\tO Regulamento, aprovado no dia 05 de set...

# %%
# Concatenando título e conteúdo
df['doc'] = df.apply(lambda row: row['titulo'] + row['conteudo'], axis=1)

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
#stopwords = normalize('NFKD', ' '.join(stopwords)).encode('ASCII', 'ignore').decode().split()

stemmer = nltk.stem.RSLPStemmer()

def processar_texto(texto):
    if texto is None or not texto:
        return ''

    # Trasnformação do texto em minúsculo e remoção de termo
    texto = texto.lower().replace('\nleia o documento\n', '')

    # Removendo acentuação
    #texto = normalize('NFKD', texto).encode('ASCII', 'ignore').decode()

    # Removendo Pontuação, stopwords, palavras com número e aplicando stemming
    texto = ' '.join([stemmer.stem(c) for c in nltk.word_tokenize(texto) 
                      if (c not in punctuation) and (c not in stopwords) and not (re.match('.*[\d_].*', c)) ])

    return texto

# %%
df['doc'] = df['doc'].apply(processar_texto)

# %%
vectorizer = TfidfVectorizer(
    analyzer='word',
    ngram_range=(1, 1),
    max_features=None,
    binary=False,
    use_idf=True
)

tfidf_matrix = vectorizer.fit_transform(df['doc'])

# %%
feature_names = vectorizer.get_feature_names()

# %%
num_topicos = 25

# %%
nmf_model = NMF(
    n_components = num_topicos,
    random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd'
).fit(tfidf_matrix)

# %%
nmf_w = nmf_model.transform(tfidf_matrix)

# %%
nmf_h = nmf_model.components_

# %%
print('Matriz W: ', nmf_w.shape)
print('Matriz H: ', nmf_h.shape)
# Out:
# Matriz W:  (1000, 25)
# Matriz H:  (25, 5873)

# %% [markdown]
# ## Atividade para casa
#
# Aplicar modelagem de tópicos ao conteúdo de um site ou API, e fazer sua análise.
